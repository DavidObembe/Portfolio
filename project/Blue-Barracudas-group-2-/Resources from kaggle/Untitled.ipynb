# %%
#import pd etc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from scipy import stats

pd.set_option('display.max_rows', 800)

# %%
#import csv files
happy15_df= pd.read_csv('../Resources/Happy15.csv')
happy16_df= pd.read_csv('../Resources/Happy16.csv')
happy17_df= pd.read_csv('../Resources/Happy17.csv')
happy18_df= pd.read_csv('../Resources/Happy18.csv')

# %%
#merge csv files 
#happy15_df.head()

# %%
happy15_df2= happy15_df.rename(columns= {'Happiness Rank':'Overall Rank','Happiness Score':'Happiness Score','Economy (GDP per Capita)':'GDP per Capita',
                           'Family':'Family', 'Health (Life Expectancy)':'Life Expectancy','Freedom':'Freedom', 'Trust (Government Corruption)':
                           'Perceptions of corruption','Generosity':'Generosity'})
happy15_df2
happy15_df2= happy15_df2.drop(['Region','Standard Error','Dystopia Residual',], axis = 1)
happy15_df2
happy15_df2['Year']= 2015
happy15_df2
column_names= ['Overall Rank','Country','Happiness Score','GDP per Capita','Family','Life Expectancy','Freedom','Generosity','Perceptions of corruption','Year']
happy15_df2= happy15_df2.reindex(columns= column_names)
happy15_df2.head()
# Out:
#    Overall Rank      Country  Happiness Score  GDP per Capita   Family  \
# 0             1  Switzerland            7.587         1.39651  1.34951
# 1             2      Iceland            7.561         1.30232  1.40223
# 2             3      Denmark            7.527         1.32548  1.36058
# 3             4       Norway            7.522         1.45900  1.33095
# 4             5       Canada            7.427         1.32629  1.32261
#
#    Life Expectancy  Freedom  Generosity  Perceptions of corruption  Year
# 0          0.94143  0.66557     0.29678                    0.41978  2015
# 1          0.94784  0.62877     0.43630                    0.14145  2015
# 2          0.87464  0.64938     0.34139                    0.48357  2015
# 3          0.88521  0.66973     0.34699                    0.36503  2015
# 4          0.90563  0.63297     0.45811                    0.32957  2015

# %%
#happy16_df.head()

# %%
happy16_df2= happy16_df.rename(columns= {'Happiness Rank':'Overall Rank','Happiness Score':'Happiness Score','Economy (GDP per Capita)':'GDP per Capita',
                           'Family':'Family', 'Health (Life Expectancy)':'Life Expectancy','Freedom':'Freedom', 'Trust (Government Corruption)':
                           'Perceptions of corruption','Generosity':'Generosity'})
happy16_df2
happy16_df2= happy16_df2.drop(['Lower Confidence Interval','Upper Confidence Interval','Dystopia Residual','Region'], axis = 1)
happy16_df2['Year']= 2016
happy16_df2
column_names= ['Overall Rank','Country','Happiness Score','GDP per Capita','Family','Life Expectancy','Freedom','Generosity','Perceptions of corruption','Year']
happy16_df2= happy16_df2.reindex(columns= column_names)
happy16_df2.head()
# Out:
#    Overall Rank      Country  Happiness Score  GDP per Capita   Family  \
# 0             1      Denmark            7.526         1.44178  1.16374
# 1             2  Switzerland            7.509         1.52733  1.14524
# 2             3      Iceland            7.501         1.42666  1.18326
# 3             4       Norway            7.498         1.57744  1.12690
# 4             5      Finland            7.413         1.40598  1.13464
#
#    Life Expectancy  Freedom  Generosity  Perceptions of corruption  Year
# 0          0.79504  0.57941     0.36171                    0.44453  2016
# 1          0.86303  0.58557     0.28083                    0.41203  2016
# 2          0.86733  0.56624     0.47678                    0.14975  2016
# 3          0.79579  0.59609     0.37895                    0.35776  2016
# 4          0.81091  0.57104     0.25492                    0.41004  2016

# %%
#happy17_df.head()

# %%
happy17_df2= happy17_df.rename(columns= {'Happiness.Rank':'Overall Rank','Happiness.Score':'Happiness Score','Economy..GDP.per.Capita.':'GDP per Capita',
                           'Family':'Family', 'Health..Life.Expectancy.':'Life Expectancy','Freedom':'Freedom', 'Trust..Government.Corruption.':
                           'Perceptions of corruption','Generosity':'Generosity'})
happy17_df2
happy17_df2= happy17_df2= happy17_df2.drop(['Whisker.high','Whisker.low','Dystopia.Residual'], axis = 1)
happy17_df2
happy17_df2['Year']= 2017
column_names= ['Overall Rank','Country','Happiness Score','GDP per Capita','Family','Life Expectancy','Freedom','Generosity','Perceptions of corruption','Year']
happy17_df2= happy17_df2.reindex(columns= column_names)
happy17_df2.head()
# Out:
#    Overall Rank      Country  Happiness Score  GDP per Capita    Family  \
# 0             1       Norway            7.537        1.616463  1.533524
# 1             2      Denmark            7.522        1.482383  1.551122
# 2             3      Iceland            7.504        1.480633  1.610574
# 3             4  Switzerland            7.494        1.564980  1.516912
# 4             5      Finland            7.469        1.443572  1.540247
#
#    Life Expectancy   Freedom  Generosity  Perceptions of corruption  Year
# 0         0.796667  0.635423    0.362012                   0.315964  2017
# 1         0.792566  0.626007    0.355280                   0.400770  2017
# 2         0.833552  0.627163    0.475540                   0.153527  2017
# 3         0.858131  0.620071    0.290549                   0.367007  2017
# 4         0.809158  0.617951    0.245483                   0.382612  2017

# %%
#happy18_df.head()

# %%
happy18_df2= happy18_df.rename(columns= {'Country or region':'Country','Score':'Happiness Score','GDP per capita':'GDP per Capita',
                           'Social support':'Family', 'Healthy life expectancy':'Life Expectancy','Freedom to make life choices':'Freedom', 'Perceptions of corruption':
                           'Perceptions of corruption','Generosity':'Generosity','Overall rank':'Overall Rank'})
happy18_df2
happy18_df2['Year']= 2018
happy18_df2.head()
#list(happy18_df2.columns) 
#happy18_df2= happy18_df2= happy18_df2.drop(['Whisker.high','Whisker.low','Dystopia.Residual'], axis = 1)
#happy18_df2
# Out:
#    Overall Rank      Country  Happiness Score  GDP per Capita  Family  \
# 0             1      Finland            7.632           1.305   1.592
# 1             2       Norway            7.594           1.456   1.582
# 2             3      Denmark            7.555           1.351   1.590
# 3             4      Iceland            7.495           1.343   1.644
# 4             5  Switzerland            7.487           1.420   1.549
#
#    Life Expectancy  Freedom  Generosity  Perceptions of corruption  Year
# 0            0.874    0.681       0.202                      0.393  2018
# 1            0.861    0.686       0.286                      0.340  2018
# 2            0.868    0.683       0.284                      0.408  2018
# 3            0.914    0.677       0.353                      0.138  2018
# 4            0.927    0.660       0.256                      0.357  2018

# %%
allFrames=[happy15_df2,happy16_df2,happy17_df2,happy18_df2]
jointFrames= pd.concat(allFrames)
jointFrames.head(160)
# Out:
#      Overall Rank                   Country  Happiness Score  GDP per Capita  \
# 0               1               Switzerland            7.587         1.39651
# 1               2                   Iceland            7.561         1.30232
# 2               3                   Denmark            7.527         1.32548
# 3               4                    Norway            7.522         1.45900
# 4               5                    Canada            7.427         1.32629
# 5               6                   Finland            7.406         1.29025
# 6               7               Netherlands            7.378         1.32944
# 7               8                    Sweden            7.364         1.33171
# 8               9               New Zealand            7.286         1.25018
# 9              10                 Australia            7.284         1.33358
# 10             11                    Israel            7.278         1.22857
# ...

# %%
countedJFrames=jointFrames.groupby('Country').count()
countedJFrames
# Out:
#                           Overall Rank  Happiness Score  GDP per Capita  \
# Country
# Afghanistan                          4                4               4
# Albania                              4                4               4
# Algeria                              4                4               4
# Angola                               4                4               4
# Argentina                            4                4               4
# Armenia                              4                4               4
# Australia                            4                4               4
# Austria                              4                4               4
# Azerbaijan                           4                4               4
# Bahrain                              4                4               4
# Bangladesh                           4                4               4
# Belarus                              4                4               4
# ...

# %%
masked_JF= (countedJFrames['Year']< 4)
clean_df =countedJFrames[masked_JF]

clean_df
# Out:
#                           Overall Rank  Happiness Score  GDP per Capita  \
# Country
# Belize                               3                3               3
# Central African Republic             3                3               3
# Comoros                              2                2               2
# Djibouti                             1                1               1
# Hong Kong                            3                3               3
# Hong Kong S.A.R., China              1                1               1
# Laos                                 3                3               3
# Lesotho                              3                3               3
# Mozambique                           3                3               3
# Namibia                              3                3               3
# North Cyprus                         3                3               3
# Northern Cyprus                      1                1               1
# ...

# %%
masked = (jointFrames['Country']== 'Belize')
first_removal =jointFrames[masked]

first_removal
# Out:
#     Overall Rank Country  Happiness Score  GDP per Capita    Family  \
# 51            52  Belize            5.956        0.876160  0.686550
# 49            50  Belize            5.956        0.907975  1.081418
# 48            49  Belize            5.956        0.807000  1.101000
#
#     Life Expectancy   Freedom  Generosity  Perceptions of corruption  Year
# 51         0.455690  0.512310    0.236840                   0.107710  2016
# 49         0.450192  0.547509    0.240016                   0.096581  2017
# 48         0.474000  0.593000    0.183000                   0.089000  2018

# %%
masked = (jointFrames['Country']== 'Hong Kong')
selection =jointFrames[masked]

selection
# Out:
#     Overall Rank    Country  Happiness Score  GDP per Capita   Family  \
# 71            72  Hong Kong            5.474         1.38604  1.05818
# 74            75  Hong Kong            5.458         1.51070  0.87021
# 75            76  Hong Kong            5.430         1.40500  1.29000
#
#     Life Expectancy  Freedom  Generosity  Perceptions of corruption  Year
# 71          1.01328  0.59608     0.39478                    0.37124  2015
# 74          0.95277  0.48079     0.40097                    0.31647  2016
# 75          1.03000  0.52400     0.24600                    0.29100  2018

# %%
#def filteredmask(Country, Hongkong):
   # masked = (jointFrames['Country']== 'Hong kong')
   # selection =jointFrames[masked]
   # selection

# %%
#for row in clean_df :
   # filteredmask(jointFrames['Country'],row['Country'])
